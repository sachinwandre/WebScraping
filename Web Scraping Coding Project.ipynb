# %%
import requests
from bs4 import BeautifulSoup
import json
import markdown
import os

# URL
base_url = 'https://www.legalbites.in/topics/articles'
output_folder = 'output'
output_file = 'webscraping_output.json'

# Creating output folder
if not os.path.exists(output_folder):
    os.mkdir(output_folder)

# Function to convert HTML tables to Markdown
def html_table_to_markdown(table):
    markdown_table = ""
    for row in table.find_all('tr'):
        for cell in row.find_all(['th', 'td']):
            markdown_table += f"|{cell.text.strip()}"
        markdown_table += "|\n"
    return markdown_table

# Function to scrape a single page
def scrape_page(url):    
    try:
        response = requests.get(url)
        #print(response.status_code)
        #soup = BeautifulSoup(response.content, 'html.parser')  
        soup = BeautifulSoup(response.text, 'html.parser')

        # Handle the case where the selector is not found
        try:
            if(soup.select_one(".main-content")):
                
                for element in soup.find_all(class_='page-numbers next last page-numbers'):
                    element.extract()
                    #print(element.extract())

                for element in soup.find_all(class_='page-numbers prev first page-numbers'):
                    element.extract()
                    #print(element.extract())           
                
                # Extract the title and content
                title = soup.title.string if soup.title else ""
                #content = soup.find_all('div', {'class': 'listing-page'}).text.strip()
                content = soup.find('div', {'class': 'listing-wrapper'}).text.strip()

                # Convert HTML tables to Markdown
                tables = soup.find_all('table')
                for table in tables:
                    table.replace_with(html_table_to_markdown(table))

                return {'title': title, 'content': content}

        except AttributeError as e:
            print(e)

    except Exception as e:
        print(f"Given url page is not found {url}: {str(e)}")
        return None


# Scraping the first 5 pages
results = []
for page_num in range(1, 6):  
    page_url = f'{base_url}/page/{page_num}'
    #print(page_url)
    page_data = scrape_page(page_url)
    print('*'*50)
    print(page_data)
    print('*'*50)
    if page_data:
        results.append(page_data)

# Save results into JSON file
with open(os.path.join(output_folder, output_file), 'w', encoding='utf-8') as file:
    json.dump(results, file, ensure_ascii=False)
# Out:
# **************************************************
# {'title': 'Articles', 'content': "Benefits of Studying Legal General Knowledgeby LB Desk\xa025 Sep 2023 10:51 AM GMT Arbitration: Introduction and Key Componentsby Dibakar Banerjee\xa022 Sep 2023 5:18 AM GMT Significance of Studying Constitutional Lawby LB Desk\xa015 Sep 2023 4:32 AM GMT The Path to Becoming a Corporate Lawyer in India: Skills and Insightsby Mayank Shekhar\xa014 Sep 2023 1:04 PM GMT Concept of Eminent Domainby Gitika Wadhwani\xa013 Sep 2023 10:39 AM GMT Supercharge Your Legal Journey with Legal Bites Subscription!by LB Desk\xa010 Sep 2023 12:53 PM GMT Protecting Your Rights: Navigating Spousal Support Claimsby Mayank Shekhar\xa07 Sep 2023 6:51 AM GMT The Benefits of Hiring a Local Car Accident Lawyerby Mayank Shekhar\xa026 Aug 2023 7:11 AM GMT How To Deal With A Car Accident At The Roadway Construction Zone?by Mayank Shekhar\xa026 Aug 2023 7:11 AM GMT Importance of Studying Landmark Judgments for Law Studentsby LB Desk\xa024 Aug 2023 5:06 AM GMT Celebrating India's 15th August: A Journey of Independence and Unityby LB Desk\xa015 Aug 2023 1:03 PM GMT India’s Central Bank Eyes Increased Fintech Regulationby LB Desk\xa04 Aug 2023 11:51 AM GMT"}
# **************************************************
# **************************************************
# {'title': 'Articles Page 2', 'content': "Guidelines for Proper Usage of Public Authorities Logos in Blogs and Publicationsby Snehil Sharma\xa01 Aug 2023 10:47 AM GMT 12 life hacks we can learn from Harvey Specterby Mayank Shekhar\xa01 Aug 2023 6:10 AM GMT Studying Code of Civil Procedure For Judiciary Examby Admin Legal Bites\xa01 Aug 2023 5:29 AM GMT World Nature Conservation Day 2023 | 28th Julyby LB Desk\xa028 July 2023 8:11 AM GMT Kargil Vijay Diwas 2023 | July 26thby LB Desk\xa026 July 2023 5:30 AM GMT Human Trafficking Peddling of a Girl's Innocenceby Khwaish Chopra\xa023 July 2023 5:05 AM GMT International Criminal Justice Day 2023 (17th July) | All You Need to Knowby LB Desk\xa017 July 2023 1:51 AM GMT The Intersection of Mental Health, Substance Abuse, and Juvenile Delinquency in Indiaby Stuti Shrivastva\xa015 July 2023 11:30 AM GMT World Youth Skills Day 2023 (15th July) | All You Need to Knowby LB Desk\xa015 July 2023 6:46 AM GMT What Type of Cases Can a Personal Injury Lawyer handle?by Himanshu Saini\xa013 July 2023 5:43 AM GMT A Glimpse of Motherhood: Maternity Benefits and Regulationsby Shreya Manoga\xa012 July 2023 8:06 AM GMT World Population Day 2023 (11th July) | All You Need to Knowby LB Desk\xa011 July 2023 11:20 AM GMT"}
# **************************************************
# **************************************************
# {'title': 'Articles Page 3', 'content': 'Is it illegal to Publish a Private Conversation in India?by Ritika Chaturvedi\xa010 July 2023 11:15 AM GMT Importance of Constitutional and Administrative Law for UPSC Law Optional Paperby Admin Legal Bites\xa08 July 2023 6:07 AM GMT The Role of Test Series in UPSC Exam Preparationby Admin Legal Bites\xa06 July 2023 11:50 AM GMT Ensuring Expertise and Excellence in Real Estate Legal Servicesby John Paul\xa06 July 2023 4:44 AM GMT The Best Strategies to Answer UPSC Law Optional Papersby Admin Legal Bites\xa03 July 2023 1:04 PM GMT Gyanvapi Mosque: Exploring the Splendour of History and Controversyby Tridha Gosain and Manu Gupta\xa029 Jun 2023 10:38 AM GMT Humane Approach to Street Dog Issuesby Manika Dass\xa028 Jun 2023 11:37 AM GMT International Day Against Drug Abuse and Illicit Trafficking | June 26thby LB Desk\xa026 Jun 2023 8:49 AM GMT Anti-Cheating Laws: Is Jail the Appropriate Response?by Sridip S. Nambiar\xa021 Jun 2023 8:24 AM GMT Implications of Using AI Algorithms in the Field of Lawby Stuti Shrivastva\xa019 Jun 2023 9:04 AM GMT Bard of Blood: Stigmatised Blood Drivesby Hemant Tewari and Manjari Tripathi\xa016 Jun 2023 5:46 AM GMT 9 Reasons Why Environmental Legal Issues Will be the Next Big Thing in Industryby Shivam Patel\xa013 Jun 2023 3:34 AM GMT'}
# **************************************************
# **************************************************
# {'title': 'Articles Page 4', 'content': "World Day Against Child Labour 2023 | 12th June | #Must Knowby LB Desk\xa012 Jun 2023 3:29 AM GMT Demystifying India's CBFC and Cinematograph Act: A Comprehensive Overviewby Dikshita More\xa06 Jun 2023 11:46 AM GMT Critical Professional Ethics: The Seven Lamps of Advocacyby Deepshikha\xa06 Jun 2023 5:27 AM GMT World Environment Day 2023 | 5th Juneby Apurva Neel\xa05 Jun 2023 10:08 AM GMT Current Concerns Regarding Women: Health and Legal Implicationsby Dikshita More\xa03 Jun 2023 7:01 AM GMT 7 Best Practices for Drafting a Clear and Precise Contract for Lawyers 2023by Mayank Shekhar\xa01 Jun 2023 5:01 AM GMT 10 Methods to Generate Income During Law Schoolby Himanshu Saini\xa029 May 2023 10:09 AM GMT 7 Best Law Schools Scholarship for Aspiring Scholarsby Mayank Shekhar\xa028 May 2023 5:52 AM GMT International Day of Action for Women's Health | 28th Mayby LB Desk\xa027 May 2023 7:30 PM GMT 7 Negotiation Skills that Every Lawyer Needs to Masterby Mayank Shekhar\xa027 May 2023 5:12 AM GMT How to Develop LinkedIn Profile as a Law Studentby Mayank Shekhar\xa025 May 2023 4:15 AM GMT Law and Advertisement in Indiaby Apurva Neel\xa024 May 2023 5:48 AM GMT"}
# **************************************************
# **************************************************
# {'title': 'Articles Page 5', 'content': 'Decoding the ITR Filing Process: A Comprehensive Guide for Indian Taxpayersby Mayank Shekhar\xa023 May 2023 1:01 PM GMT 7 Highly Sought-After Legal Careers in 2023by Mayank Shekhar\xa023 May 2023 12:53 PM GMT Woman’s Rights Over Her Body- A Critical and Comparative Analysisby Saakshi S. Rawat\xa023 May 2023 3:46 AM GMT International Day for Biological Diversity (22nd May) | The Core Essentialsby LB Desk\xa022 May 2023 5:08 PM GMT Noise Pollution and Regulatory Frameworkby Apurva Neel\xa022 May 2023 5:35 AM GMT Ten Skills Required in a Mooter | # Mooting Skillsby Mayank Shekhar\xa022 May 2023 3:34 AM GMT Role of Mock Tests in UGC NET Law Preparation: Enhancing Performanceby Law Aspirants\xa022 May 2023 3:32 AM GMT The Intersection of Human Rights and Environmental Lawby Dikshita More\xa018 May 2023 9:52 AM GMT Why Should You Focus on Evidence Act During College Days?by LB Desk\xa018 May 2023 5:43 AM GMT 10 Skills for a Successful Law Careerby LB Desk\xa018 May 2023 5:17 AM GMT Embracing Nature: Celebrating National Love A Tree Day | 16th Mayby LB Desk\xa016 May 2023 3:00 PM GMT Criminal Law and Virtual Reality: Exploring the Legal Challenges of Virtual Crimes and Virtual Worldby Arghya Sen\xa015 May 2023 8:08 AM GMT'}
# **************************************************
